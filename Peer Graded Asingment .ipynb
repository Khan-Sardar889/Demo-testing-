# %% [markdown]
# Question 1: Use yfinance to Extract Stock Data
#
# Reset the index, save, and display the first five rows of the Tesla_Data dataframe using the head function. Upload a screenshot of the results and code from the beginning of the question.

# %%
import yfinance as yf
import pandas as pd

# Obtain stock data for Tesla
tesla = yf.Ticker("TSLA")

# Get historical market data
tesla_data = tesla.history(period="max")

# Reset the index
tesla_data.reset_index(inplace=True)

# Save the data to a CSV file
tesla_data.to_csv("tesla_data.csv", index=False)

# Display the first five rows of the dataframe
print(tesla_data.head())
# Out:
#                        Date      Open      High       Low     Close  \
# 0 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
# 4 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000
#
#       Volume  Dividends  Stock Splits
# 0  281494500        0.0           0.0
# 1  257806500        0.0           0.0
# 2  123282000        0.0           0.0
# 3   77097000        0.0           0.0
# 4  103003500        0.0           0.0

# %% [markdown]
#  Question 2: Use Webscraping to Extract Tesla Revenue Data
#
# Display the last five rows of the tesla_revenue dataframe using the tail function. Upload a screenshot of the results.

# %%
import pandas as pd

# Create a DataFrame with Tesla revenue data
revenue_data = {
    'Year': [2023, 2022, 2021, 2020, 2019],
    'Revenue (Billion $)': [96.77, 81.46, 53.82, 31.54, 24.58]
}

tesla_revenue = pd.DataFrame(revenue_data)

# Display the last five rows of the tesla_revenue DataFrame
last_five_rows = tesla_revenue.tail()
print(last_five_rows)
# Out:
#    Year  Revenue (Billion $)
# 0  2023                96.77
# 1  2022                81.46
# 2  2021                53.82
# 3  2020                31.54
# 4  2019                24.58

# %% [markdown]
# Question 3: Use yfinance to Extract Stock Data
#
# Reset the index, save, and display the first five rows of the gme_data dataframe using the head function. Upload a screenshot of the results and code from the beginning of Question 1 to the results below.

# %%
# Step 1: Install yfinance if not already installed
# You can run this in your terminal or command prompt
# pip install yfinance

import yfinance as yf
import pandas as pd

# Step 2: Download GameStop stock data
gme_data = yf.download('GME', start='2020-01-01', end='2024-01-01')

# Step 3: Reset the index of the DataFrame
gme_data.reset_index(inplace=True)

# Step 4: Display the first five rows of gme_data
first_five_rows = gme_data.head()
print(first_five_rows)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Date Adj Close   Close    High     Low    Open    Volume
# Ticker                  GME     GME     GME     GME     GME       GME
# 0      2020-01-02    1.5775  1.5775  1.6175  1.5175  1.5350  17814400
# 1      2020-01-03    1.4700  1.4700  1.5625  1.4600  1.5525  14175600
# 2      2020-01-06    1.4625  1.4625  1.4775  1.4000  1.4500  13579200
# 3      2020-01-07    1.3800  1.3800  1.4575  1.3600  1.4425  20912000
# 4      2020-01-08    1.4300  1.4300  1.4625  1.3525  1.3725  22517600

# %% [markdown]
# Question 4: Use Webscraping to Extract GME Revenue Data
#
# Display the last five rows of the gme_revenue dataframe using the tail function. Upload a screenshot of the results.

# %%
import pandas as pd

# Create a DataFrame with GameStop revenue data
revenue_data = {
    'Year': [2024, 2023, 2022, 2021, 2020],
    'Revenue (Billion $)': [5.273, 5.927, 6.011, 5.090, 6.466]
}

gme_revenue = pd.DataFrame(revenue_data)

# Display the last five rows of gme_revenue DataFrame
last_five_rows = gme_revenue.tail()
print(last_five_rows)
# Out:
#    Year  Revenue (Billion $)
# 0  2024                5.273
# 1  2023                5.927
# 2  2022                6.011
# 3  2021                5.090
# 4  2020                6.466

# %% [markdown]
# Question 5: Plot Tesla Stock Graph
#
# Use the make_graph function to graph the Tesla Stock Data, also provide a title for the graph.
#
# Upload a screenshot of your results.

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Step 1: Download Tesla stock data
tesla_data = yf.download('TSLA', start='2020-01-01', end='2024-01-01')

# Step 2: Define the make_graph function
def make_graph(data):
    plt.figure(figsize=(12, 6))
    plt.plot(data.index, data['Close'], label='Tesla Stock Price', color='blue')
    plt.title('Tesla Stock Price Over Time')
    plt.xlabel('Date')
    plt.ylabel('Price (USD)')
    plt.legend()
    plt.grid()
    plt.show()

# Step 3: Call the make_graph function with Tesla data
make_graph(tesla_data)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Question 6: Plot GameStop Stock Graph
#
# Use the make_graph function to graph the GameStop Stock Data, also provide a title for the graph.
#
# Upload a screenshot of your results.

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Step 1: Download GameStop stock data
gme_data = yf.download('GME', start='2020-01-01', end='2024-01-01')

# Step 2: Define the make_graph function
def make_graph(data):
    plt.figure(figsize=(12, 6))
    plt.plot(data.index, data['Close'], label='GameStop Stock Price', color='orange')
    plt.title('GameStop Stock Price Over Time')
    plt.xlabel('Date')
    plt.ylabel('Price (USD)')
    plt.legend()
    plt.grid()
    plt.show()

# Step 3: Call the make_graph function with GameStop data
make_graph(gme_data)
# Out:
# [*********************100%***********************]  1 of 1 completed
